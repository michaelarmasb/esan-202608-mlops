# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %%
ruta_base_atributos = 'esan202608.mlops.base_atributos'
ruta_base_trx = 'esan202608.mlops.base_trx'
ruta_base_cliente = 'esan202608.mlops.base_cliente'

# %%
# Leer la tabla usando Spark
df_atributos_sp = spark.table(ruta_base_atributos)
df_trx_sp = spark.table(ruta_base_trx)
df_cliente_sp = spark.table(ruta_base_cliente)

# %%
# Si quieres pasarlo a Pandas
df_atributos = df_atributos_sp.toPandas()
df_trx = df_trx_sp.toPandas()
df_cliente = df_cliente_sp.toPandas()

# %%
df_cliente = df_cliente.drop(columns=['periodo'])

# %%
df = df_trx.merge(df_cliente, on=['id_cliente'], how='left')
df = df.merge(df_atributos, on=['periodo', 'id_cliente'], how="left")

# %%
df_trx.shape[0], df.shape[0]
# Out:
# (1403815, 1403815)

# %%
df = df[(df['flg_churn']== 0) | (df['flg_churn']== 1)]

# %%
df = df[~df['tasa'].isnull()]
df = df[~df['periodo_creacion'].isnull()]
df = df[~df['tipo_producto'].isnull()]
df = df[~df['segmento_pago'].isnull()]
df = df[~df['canal'].isnull()]
df = df[~df['segmento_cliente'].isnull()]
df = df[~df['crossell'].isnull()]
df = df[~df['departamento'].isnull()]

# %%
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# ultima_compra_2m     53510
# ultima_compra_3m     77959
# incidencias_a       352342
# incidencias_b       302146
# dtype: int64

# %%
df['flg_churn'] = df['flg_churn'].astype(int)
df['segmento_cliente'] = df['segmento_cliente'].astype(int)

# %%
df.dtypes
# Out:
# periodo                  int64
# id_cliente               int64
# tasa                   float64
# monto_1m               float64
# monto_2m               float64
# monto_3m               float64
# monto_4m               float64
# monto_5m               float64
# monto_6m               float64
# cantidad_1m            float64
# cantidad_2m            float64
# cantidad_3m            float64
# cantidad_6m            float64
# frecuencia_1m          float64
# frecuencia_2m          float64
# frecuencia_3m          float64
# ultima_compra_1m       float64
# ultima_compra_2m       float64
# ultima_compra_3m       float64
# flg_churn                int64
# __index_level_0___x      int64
# tipo_producto           object
# periodo_creacion       float64
# departamento            object
# segmento_pago          float64
# canal                   object
# segmento_cliente         int64
# crossell               float64
# __index_level_0___y    float64
# tiempo_permanencia       int64
# flg_vip                float64
# incidencias_a          float64
# incidencias_b          float64
# __index_level_0__        int64
# dtype: object

# %%
# Convertir a Spark DataFrame
df_spark = spark.createDataFrame(df)

# Guardar en el catálogo
df_spark.write.mode("overwrite").saveAsTable("esan202608.mlops.base")
